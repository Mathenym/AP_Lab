# %%
import numpy as np
import uproot 
import matplotlib.pyplot as plt
from Hist_plot import * 
from peak_fit import *

# %%
Energy = []
for arrays in uproot.iterate("Det_65008-01994_NaI_1000V_22Na/FILTERED/*.root","Data_F","CalibEnergy",outputtype=list):
    
    for x in arrays:
        Energy.extend(x)

# %%
hist_uncal(Energy,3000)
# Out:
# 12048.0 0.0

# %%
c0 = -13.47
c1 = 3.5923
 #calibrated
E_cal = []
for x in Energy:
    E = c1*x + c0
    E_cal.append(E)

# %%
hist_cal(E_cal,3000)
# Out:
# 43266.560399999995 -13.47
